# %%
import os.path
from collections import defaultdict

from seleniumbase import Driver

driver = Driver()
driver.open("https://untappd.com/")

# %%
import dataclasses


@dataclasses.dataclass()
class BeerPriceSql:
    url: str
    name: str
    style: str
    abv: float
    ibu: int
    brewery: str
    rate: float
    volume: str
    price: float
    date_parsed: str
    venue: str
    img: str

# %%
import re
from selenium.common import NoSuchElementException


def parse_beers(venue, venue_url, date_parsed):
    if driver.get_current_url() != venue_url:
        driver.open(venue_url)

    menu_items = driver.find_elements(".menu-item")

    beers = []
    for menu_item in menu_items:
        # 'https://untappd.com/b/augustine-avgustin-kin-dza-dza/6091216'
        href = menu_item.find_element("css selector", "a").get_attribute("href")
        # 'КИН-ДЗА-ДЗА'
        beer_name = menu_item.find_element("css selector", "a").text.strip()
        beer_name = re.sub("^\d+\.\s", "", beer_name)
        # 'Sour - Tomato / Vegetable Gose'
        emphasis_text = menu_item.find_element("css selector", "em").text.strip()
        # '4.9% ABV • 3 IBU • Augustine (Августин) •\n(3.92)'
        heading_text = menu_item.find_element("css selector", "h6").text.strip()

        img = menu_item.find_element("css selector", "img").get_attribute("src")

        # '0.5L Can\n268.00 RUB'
        volumes = []
        try:
            prices_text = menu_item.find_element("css selector", ".beer-prices").text.strip()
            volumes_and_prices_raw = list(filter(None, prices_text.splitlines()))
            for i in range(0, len(volumes_and_prices_raw), 2):
                try:
                    volume, price = volumes_and_prices_raw[i], volumes_and_prices_raw[i+1]
                except IndexError:
                    continue
                try:
                    price = float(price.split()[0])
                except ValueError:
                    continue
                volumes.append((volume, price))
        except NoSuchElementException:
            volumes = [("0", 0)]

        abv, ibu, brewery, rate = heading_text.split('•')
        abv = 0 if abv.startswith("N/A") else float(abv.split("%", 1)[0])

        parsed_ibu = ibu.strip().split()[0]
        ibu = 0 if parsed_ibu == 'N/A' else int(parsed_ibu)
        brewery = brewery.strip()
        parsed_rate = rate.strip().strip("()")
        rate = 0 if parsed_rate == 'N/A' else float(parsed_rate)

        for volume, price in volumes:
            beer = BeerPriceSql(
                url=href,
                name=beer_name,
                style=emphasis_text,
                abv=abv,
                ibu=ibu,
                brewery=brewery,
                rate=rate,
                volume=volume,
                price=price,
                date_parsed=date_parsed,
                venue=venue,
                img=img,
            )
            print(beer)
            beers.append(beer)

    print(f"Parsed {len(beers)}")
    return beers

# %%
from pathlib import Path
import os

db_path = Path(os.getcwd()).parent / "beer.db"

# %%
import sqlite3
from typing import List, NamedTuple


def insert_beers_to_db(beers: List[BeerPriceSql], db_path: str) -> None:
    # Подключаемся к базе данных
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    # Подготавливаем данные для вставки
    beer_data = [(
        beer.url,
        beer.name,
        beer.style,
        beer.abv,
        beer.ibu,
        beer.brewery,
        beer.rate,
        beer.volume,
        beer.price,
        beer.date_parsed,
        beer.venue,
        beer.img,
    ) for beer in beers]

    # Вставляем данные
    cursor.executemany('''
        INSERT INTO untappd_beer_prices (url, name, style, abv, ibu, brewery, rate, volume, price, date_parsed, venue, img)
        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
    ''', beer_data)

    # Сохраняем изменения и закрываем соединение
    conn.commit()
    conn.close()

# %%
from typing import List, NamedTuple


class Venue(NamedTuple):
    name: str
    list_name: str
    list_url: str

venues = [
    # Venue("СуперХмель", "Bottle List", "https://untappd.com/v/superhmel/10587734"),
    # Venue('Eric the Red', 'Второй этаж', 'https://untappd.com/v/eric-the-red/3797427?menu_id=32466'),
    # Venue('Eric the Red', 'Первый этаж', 'https://untappd.com/v/eric-the-red/3797427?menu_id=32580'),
    # Venue('Eric the Red', '-1 этаж', 'https://untappd.com/v/eric-the-red/3797427?menu_id=32583'),
    # Venue('Eric the Red', 'Bottle List', 'https://untappd.com/v/eric-the-red/3797427?menu_id=4873'),
    # Venue('Share House', 'Bottles', 'https://untappd.com/v/share-house/7728362?menu_id=48054'),
    # Venue('Share House', 'Taps', 'https://untappd.com/v/share-house/7728362?menu_id=49451'),
    # # Venue('Share House', 'Топовые забугорные', 'https://untappd.com/v/share-house/7728362?menu_id=199538'),
    # Venue('Craft Republic', 'Bottles', 'https://untappd.com/v/craft-republic/2180553?menu_id=6716'),
    # Venue('Craft Republic', 'Taps', 'https://untappd.com/v/craft-republic/2180553?menu_id=43397'),
    # Venue('Магазин - Бар "Имею Право!" Академическая', 'Taps', 'https://untappd.com/v/magazin-bar-imeyu-pravo-akademicheskaya/12588903'),
    # Venue('Магазин - Бар "Имею Право!" Академическая', 'Bottles', 'https://untappd.com/v/magazin-bar-imeyu-pravo-akademicheskaya/12588903?menu_id=215414'),
    # Venue('Магазин-Бар «Имею Право!»', 'Taps', 'https://untappd.com/v/magazinbar-imeyu-pravo/9395517'),
    # Venue('Магазин-Бар «Имею Право!»', 'Bottles', 'https://untappd.com/v/magazinbar-imeyu-pravo/9395517?menu_id=94686'),
    # Venue('Магазин-Бар «Имею Право!»', 'Sale', 'https://untappd.com/v/magazinbar-imeyu-pravo/9395517?menu_id=102981'),
    # Venue("RULE taproom", "TAP LIST", "https://untappd.com/v/rule-taproom/3363317"),
    Venue("RULE taproom", "BOTTLE/CAN LIST", "https://untappd.com/v/rule-taproom/3363317?menu_id=94708"),
    Venue("4Brewers Pub Moscow", "Пиво", "https://untappd.com/v/4brewers-pub-moscow/12248540"),

    Venue("Братья Крафт", "Tap List", "https://untappd.com/v/bratya-kraftcraft-brothers/3943033?menu_id=6133"),
    Venue("Братья Крафт", "Bottles & Cans - Russian", "https://untappd.com/v/bratya-kraftcraft-brothers/3943033?menu_id=6159"),
    Venue("Братья Крафт", "Bottles & Cans - Imported", "https://untappd.com/v/bratya-kraftcraft-brothers/3943033?menu_id=144269"),

]

# %%
import datetime
today = datetime.datetime.now().strftime("%Y-%m-%d")
print(today)

for venue in venues:
    print(f"Parsing {venue.name}")
    beers = parse_beers(venue.name, venue.list_url, today)
    insert_beers_to_db(beers, db_path)
# Out:
# 2025-03-19
# Parsing RULE taproom
# BeerPriceSql(url='https://untappd.com/b/horror-brewing-groovipa/6039990', name='Groovipa', style='IPA - American', abv=7.5, ibu=46, brewery='Horror Brewing', rate=3.91, volume='500ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6039990')
# BeerPriceSql(url='https://untappd.com/b/horror-brewing-the-silent-witness/6149310', name='The Silent Witness', style='Pale Ale - American', abv=5.8, ibu=0, brewery='Horror Brewing', rate=3.96, volume='450ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6149310')
# BeerPriceSql(url='https://untappd.com/b/jaws-brewery-jaws-apa/480265', name='Jaws APA', style='Pale Ale - American', abv=5.2, ibu=43, brewery='Jaws Brewery', rate=3.87, volume='500ml Bottle', price=380.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/480265')
# BeerPriceSql(url='https://untappd.com/b/lough-gill-brewery-rising-wind/5836633', name='Rising Wind', style='IPA - New England / Hazy', abv=6.2, ibu=0, brewery='Lough Gill Brewery', rate=3.72, volume='440ml Can', price=550.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5836633')
# BeerPriceSql(url='https://untappd.com/b/plan-b-brewery-fenris/6178814', name='Fenris', style='IPA - American', abv=6.7, ibu=40, brewery='Plan B Brewery', rate=3.75, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6178814')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-adhesive/6171621', name='Adhesive', style='IPA - Triple New England / Hazy', abv=9.5, ibu=0, brewery='Stamm Brewing', rate=3.99, volume='450ml Can', price=520.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6171621')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-biting-wind/6170138', name='Biting Wind', style='IPA - American', abv=6.5, ibu=0, brewery='Stamm Brewing', rate=3.88, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6170138')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-cloud-bird/6178794', name='Cloud Bird', style='IPA - New England / Hazy', abv=6.5, ibu=0, brewery='Stamm Brewing', rate=4.06, volume='450ml Can', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6178794')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-lunar-trail/6173795', name='Lunar Trail', style='Pale Ale - American', abv=4.7, ibu=0, brewery='Stamm Brewing', rate=3.86, volume='450ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6173795')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-shortcut/6147758', name='Shortcut', style='IPA - American', abv=6.5, ibu=0, brewery='Stamm Brewing', rate=3.95, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6147758')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-cave/5374218', name='CAVE', style='IPA - Cold', abv=6.5, ibu=45, brewery='Zagovor Brewery', rate=3.96, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5374218')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-fractal/2286684', name='FRACTAL', style='IPA - New England / Hazy', abv=6.5, ibu=43, brewery='Zagovor Brewery', rate=3.98, volume='500ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2286684')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-hazyleaks/2084054', name='HazyLeaks', style='IPA - New England / Hazy', abv=6.7, ibu=55, brewery='Zagovor Brewery', rate=4.06, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2084054')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-making-friends/2212166', name='Making Friends', style='IPA - New England / Hazy', abv=6.5, ibu=40, brewery='Zagovor Brewery', rate=3.96, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2212166')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-match-enigma-galaxy-eclipse/5633873', name='Match: Enigma, Galaxy, Eclipse', style='IPA - New England / Hazy', abv=6.5, ibu=30, brewery='Zagovor Brewery', rate=3.98, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5633873')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-match-motueka-lotus-eclipse/5461138', name='Match: Motueka, Lotus, Eclipse', style='IPA - New England / Hazy', abv=6.5, ibu=30, brewery='Zagovor Brewery', rate=4.04, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5461138')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-match-nectaron-sultana-vista/5451317', name='Match: Nectaron, Sultana, Vista', style='IPA - New England / Hazy', abv=6.5, ibu=30, brewery='Zagovor Brewery', rate=4.07, volume='500ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5451317')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-pixel/1632372', name='PIXEL', style='IPA - American', abv=7.0, ibu=65, brewery='Zagovor Brewery', rate=3.89, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/1632372')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-rapid-decompression/5704988', name='Rapid Decompression', style='IPA - New England / Hazy', abv=6.5, ibu=30, brewery='Zagovor Brewery', rate=4.17, volume='500ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5704988')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-replica-krush-hbc-586/5226559', name='Replica: Krush (HBC 586)', style='IPA - New England / Hazy', abv=6.0, ibu=30, brewery='Zagovor Brewery', rate=3.98, volume='500ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5226559')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-replica-motueka/6108098', name='Replica: Motueka', style='IPA - New England / Hazy', abv=6.0, ibu=30, brewery='Zagovor Brewery', rate=4.01, volume='450ml Bottle', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6108098')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-replica-nelson-sauvin/6186922', name='Replica: Nelson Sauvin', style='IPA - New England / Hazy', abv=6.5, ibu=25, brewery='Zagovor Brewery', rate=4.23, volume='450ml Can', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6186922')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-slow-and-trve-ddh-lupulin-powder/3007609', name='SLOW & TRVE: DDH+Lupulin Powder', style='Pale Ale - New England / Hazy', abv=4.8, ibu=35, brewery='Zagovor Brewery', rate=4.04, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3007609')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-stop-n-go-ddh-lupulin-powder/2502871', name="STOP'N'GO: DDH+Lupulin Powder", style='IPA - New England / Hazy', abv=7.0, ibu=45, brewery='Zagovor Brewery', rate=4.11, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2502871')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-sadwave-ipa/2446110', name='Sadwave IPA', style='IPA - New England / Hazy', abv=6.5, ibu=42, brewery='Zagovor Brewery', rate=4.01, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2446110')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-street-justice-citra/2449774', name='Street Justice // Citra', style='IPA - Imperial / Double', abv=8.0, ibu=85, brewery='Zagovor Brewery', rate=4.04, volume='450ml Can', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2449774')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-volume/6092519', name='Volume', style='IPA - American', abv=6.0, ibu=55, brewery='Zagovor Brewery', rate=4.05, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6092519')
# BeerPriceSql(url='https://untappd.com/b/af-brew-black-magic/463804', name='Black Magic', style='Porter - American', abv=5.8, ibu=41, brewery='AF Brew', rate=3.7, volume='330ml Bottle', price=320.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/463804')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-dochter-van-de-korenaar-sans-pardon/990955', name='Sans Pardon', style='Stout - Russian Imperial', abv=11.0, ibu=50, brewery='Brouwerij De Dochter van de Korenaar', rate=3.83, volume='330ml Bottle', price=640.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/990955')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-kees-barrel-project-2024-midnight-black/5884098', name='Barrel Project 2024 Midnight Black', style='Stout - Russian Imperial', abv=14.9, ibu=65, brewery='Brouwerij Kees', rate=4.0, volume='330ml Can', price=960.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5884098')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-rullquin-2020-2021/5429763', name='Rullquin (2020-2021)', style='Sour - Other', abv=7.0, ibu=0, brewery='Gueuzerie Tilquin', rate=4.09, volume='750ml Bottle', price=2150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5429763')
# BeerPriceSql(url='https://untappd.com/b/jaws-brewery-oatmeal-stout/431371', name='Oatmeal Stout', style='Stout - Oatmeal', abv=5.2, ibu=23, brewery='Jaws Brewery', rate=3.75, volume='500ml Bottle', price=350.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/431371')
# BeerPriceSql(url='https://untappd.com/b/red-button-brewery-dehaviland-batch-2/5775242', name='Dehaviland (Batch#2)', style='Stout - Imperial / Double', abv=8.6, ibu=0, brewery='Red Button Brewery', rate=3.89, volume='500ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5775242')
# BeerPriceSql(url='https://untappd.com/b/red-button-brewery-most-wonderful-time-4-a-beer/2427008', name='Most Wonderful Time 4 A Beer', style='Stout - Milk / Sweet', abv=5.0, ibu=30, brewery='Red Button Brewery', rate=3.95, volume='500ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2427008')
# BeerPriceSql(url='https://untappd.com/b/red-button-brewery-most-wonderful-time-4-a-beer-7-yrs-anniversary/6123637', name='Most Wonderful Time 4 A Beer (7 YRS Anniversary)', style='Stout - Milk / Sweet', abv=5.0, ibu=0, brewery='Red Button Brewery', rate=3.98, volume='500ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6123637')
# BeerPriceSql(url='https://untappd.com/b/red-button-brewery-pure-shores/2502623', name='Pure Shores', style='Stout - Milk / Sweet', abv=6.5, ibu=45, brewery='Red Button Brewery', rate=3.75, volume='500ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2502623')
# BeerPriceSql(url='https://untappd.com/b/sabotage-sweet-disaster-orange-wave/6098096', name='Sweet Disaster: Orange Wave', style='Stout - Milk / Sweet', abv=7.0, ibu=0, brewery='Sabotage', rate=3.86, volume='500ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6098096')
# BeerPriceSql(url='https://untappd.com/b/snowcap-brewing-nuotivo/6098231', name='Nuotivo', style='Stout - Imperial / Double Oatmeal', abv=8.5, ibu=30, brewery='Snowcap Brewing', rate=3.91, volume='500ml Can', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6098231')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-black-beard/991376', name='Black Beard', style='Stout - Oatmeal', abv=6.0, ibu=23, brewery='Stamm Brewing', rate=3.82, volume='500ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/991376')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-decontrol-ginger-bread/6181964', name='Decontrol: Ginger Bread', style='Porter - Imperial / Double', abv=10.5, ibu=0, brewery='Zagovor Brewery', rate=4.14, volume='450ml Can', price=600.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6181964')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-scratch/823908', name='Scratch', style='Stout - Oatmeal', abv=5.0, ibu=0, brewery='Zagovor Brewery', rate=3.74, volume='450ml Can', price=380.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/823908')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-stoner/873889', name='Stoner', style='Stout - Milk / Sweet', abv=5.5, ibu=23, brewery='Zagovor Brewery', rate=3.85, volume='500ml Can', price=380.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/873889')
# BeerPriceSql(url='https://untappd.com/b/4brewers-doza-apple-pear-goosberry-vanilla/4355606', name='Доза [Apple + Pear + Goosberry + Vanilla]', style='Sour - Smoothie / Pastry', abv=6.9, ibu=0, brewery='4BREWERS', rate=4.08, volume='450ml Can', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4355606')
# BeerPriceSql(url='https://untappd.com/b/4brewers-doza-banana-guava-mango/5396628', name='Доза [Banana + Guava + Mango]', style='Sour - Smoothie / Pastry', abv=6.0, ibu=0, brewery='4BREWERS', rate=4.14, volume='450ml Can', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5396628')
# BeerPriceSql(url='https://untappd.com/b/4brewers-doza-mango-pineapple-grapefruit/4989686', name='Доза [Mango + Pineapple + Grapefruit]', style='Sour - Smoothie / Pastry', abv=6.0, ibu=0, brewery='4BREWERS', rate=4.28, volume='450ml Can', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4989686')
# BeerPriceSql(url='https://untappd.com/b/4brewers-doza-multifruit/5087654', name='Доза [Multifruit]', style='Sour - Smoothie / Pastry', abv=6.0, ibu=0, brewery='4BREWERS', rate=4.28, volume='450ml Can', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5087654')
# BeerPriceSql(url='https://untappd.com/b/4brewers-doza-peach-apricot-pineapple-vanilla/4627565', name='Доза [Peach+Apricot+Pineapple+Vanilla]', style='Sour - Smoothie / Pastry', abv=6.9, ibu=0, brewery='4BREWERS', rate=4.21, volume='450ml Can', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4627565')
# BeerPriceSql(url='https://untappd.com/b/4brewers-zavisimost/2913906', name='Зависимость', style='Sour - Tomato / Vegetable Gose', abv=5.0, ibu=0, brewery='4BREWERS', rate=4.1, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2913906')
# BeerPriceSql(url='https://untappd.com/b/4brewers-michelada-znaet-kak-nado/6155148', name='Мичелада знает как надо', style='Sour - Tomato / Vegetable Gose', abv=5.0, ibu=0, brewery='4BREWERS', rate=4.12, volume='450ml Can', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6155148')
# BeerPriceSql(url='https://untappd.com/b/4brewers-ostraya-zavisimost/3009896', name='Острая зависимость', style='Sour - Tomato / Vegetable Gose', abv=6.9, ibu=0, brewery='4BREWERS', rate=4.14, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3009896')
# BeerPriceSql(url='https://untappd.com/b/4brewers-tot-samyj-podarok/6178174', name='Тот самый подарок', style='Sour - Smoothie / Pastry', abv=6.0, ibu=0, brewery='4BREWERS', rate=4.28, volume='450ml Can', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6178174')
# BeerPriceSql(url='https://untappd.com/b/af-brew-sangre-fresca/3607569', name='Sangre Fresca', style='Sour - Other Gose', abv=4.8, ibu=0, brewery='AF Brew', rate=3.74, volume='330ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3607569')
# BeerPriceSql(url='https://untappd.com/b/belgoo-van-aert-gueuze-artisanale/5814484', name='Van Aert Gueuze Artisanale', style='Lambic - Gueuze', abv=6.2, ibu=0, brewery='Belgoo', rate=4.01, volume='750ml Bottle', price=2150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5814484')
# BeerPriceSql(url='https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-metodo-classico-riserva-2018/5351285', name='METODO CLASSICO - RISERVA 2018', style='Bière de Champagne / Bière Brut', abv=9.0, ibu=12, brewery='BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery', rate=3.99, volume='750ml Bottle', price=3700.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5351285')
# BeerPriceSql(url='https://untappd.com/b/black-cat-brewery-culture-code-pastila-black-currant/4420241', name='Culture Code: Pastila Black Currant', style='Sour - Smoothie / Pastry', abv=4.5, ibu=0, brewery='Black Cat Brewery', rate=4.21, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4420241')
# BeerPriceSql(url='https://untappd.com/b/boerenerf-alsacien-bottle-version-2023/5790067', name='Alsacien (Bottle Version) (2023)', style='Lambic - Fruit', abv=6.0, ibu=0, brewery='Boerenerf', rate=3.97, volume='750ml Bottle', price=3500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5790067')
# BeerPriceSql(url='https://untappd.com/b/boerenerf-biet-2022/5372727', name='Biet (2022)', style='Lambic - Other', abv=7.0, ibu=0, brewery='Boerenerf', rate=4.09, volume='750ml Bottle', price=3800.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5372727')
# BeerPriceSql(url='https://untappd.com/b/boerenerf-charent-euse-2023/5784206', name="Charent'euse (2023)", style='Lambic - Gueuze', abv=7.7, ibu=0, brewery='Boerenerf', rate=4.25, volume='750ml Bottle', price=3200.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5784206')
# BeerPriceSql(url='https://untappd.com/b/boerenerf-fluweel-2023/5784174', name='Fluweel (2023)', style='Lambic - Other', abv=6.9, ibu=0, brewery='Boerenerf', rate=4.12, volume='750ml Bottle', price=3850.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5784174')
# BeerPriceSql(url='https://untappd.com/b/boerenerf-lambic-ado-2023/5784196', name="Lambic'ado (2023)", style='Lambic - Other', abv=7.1, ibu=0, brewery='Boerenerf', rate=4.25, volume='750ml Bottle', price=3200.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5784196')
# BeerPriceSql(url='https://untappd.com/b/boerenerf-roodneus-oogst-2022/5508061', name='Roodneus (Oogst 2022)', style='Lambic - Fruit', abv=7.0, ibu=0, brewery='Boerenerf', rate=4.08, volume='750ml Bottle', price=3800.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5508061')
# BeerPriceSql(url='https://untappd.com/b/brasserie-atrium-saison-passion/5152603', name='Saison Passion', style='Sour - Other', abv=6.9, ibu=0, brewery='Brasserie Atrium', rate=3.89, volume='750ml Bottle', price=1750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5152603')
# BeerPriceSql(url='https://untappd.com/b/brasserie-cantillon-kriek-100-lambic-bio-2024/5685869', name='Kriek 100% Lambic Bio (2024)', style='Lambic - Kriek', abv=6.0, ibu=0, brewery='Brasserie Cantillon', rate=4.28, volume='375ml Bottle', price=2150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5685869')
# BeerPriceSql(url='https://untappd.com/b/brasserie-la-malpolon-gardees/5549853', name='GARDÉES', style='Farmhouse Ale - Bière de Garde', abv=8.4, ibu=40, brewery='Brasserie La Malpolon', rate=3.98, volume='750ml Bottle', price=2350.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5549853')
# BeerPriceSql(url='https://untappd.com/b/brasserie-la-malpolon-magaland/5293950', name='MAGALAND', style='Sour - Other', abv=6.8, ibu=7, brewery='Brasserie La Malpolon', rate=3.89, volume='750ml Bottle', price=2150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5293950')
# BeerPriceSql(url='https://untappd.com/b/brasserie-la-malpolon-saison-du-chai-2023/5691820', name='SAISON DU CHAI 2023', style='Farmhouse Ale - Saison', abv=6.0, ibu=25, brewery='Brasserie La Malpolon', rate=3.93, volume='750ml Bottle', price=2350.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5691820')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-framboos-oogst-2019-season-19-20-blend-no-11/4172970', name='3 Fonteinen Framboos Oogst 2019 (season 19|20) Blend No. 11', style='Lambic - Framboise', abv=6.2, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.24, volume='375ml Bottle', price=2600.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4172970')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-season-22-23-blend-no-81/5969055', name='3 Fonteinen Oude Geuze (season 22|23) Blend No. 81', style='Lambic - Gueuze', abv=6.0, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.14, volume='375ml Bottle', price=1550.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5969055')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-cuvee-armand-and-gaston-season-22-23-blend-no-5/5471916', name='3 Fonteinen Oude Geuze Cuvée Armand & Gaston (season 22|23) Blend No. 5', style='Lambic - Gueuze', abv=7.2, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.04, volume='375ml Bottle', price=2150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5471916')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-pruim-mirabelle-season-22-23-blend-no-23/5755257', name='3 Fonteinen Pruim Mirabelle (season 22|23) Blend No. 23', style='Lambic - Fruit', abv=6.8, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.22, volume='375ml Bottle', price=2650.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5755257')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-rabarber-schaarbeekse-season-22-23-blend-no-100/5857613', name='3 Fonteinen Rabarber / Schaarbeekse (season 22|23) Blend No. 100', style='Lambic - Fruit', abv=6.3, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.37, volume='750ml Bottle', price=4750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5857613')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-x-ognostro-druif-fiano-season-22-23-blend-no-19/5697131', name='3 Fonteinen X Ognostro - Druif Fiano (season 22|23) Blend No. 19', style='Lambic - Fruit', abv=6.7, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.19, volume='750ml Bottle', price=4850.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5697131')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-speling-van-het-lot-xi-xii-pruim-haganta/5790055', name='Speling van het Lot XI.xii: Pruim Haganta', style='Lambic - Fruit', abv=6.2, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.26, volume='750ml Bottle', price=4750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5790055')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-speling-van-het-lot-xi-xiii-pruim-queen-victoria/5790056', name='Speling van het Lot XI.xiii: Pruim Queen Victoria', style='Lambic - Fruit', abv=6.4, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.12, volume='750ml Bottle', price=4750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5790056')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-alvinne-freddy-meets-johnny/5733225', name='Freddy Meets Johnny', style='Sour - Flanders Oud Bruin', abv=6.5, ibu=0, brewery='Brouwerij Alvinne', rate=3.84, volume='330ml Bottle', price=980.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5733225')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-boon-kriek-mariage-parfait/46538', name='Kriek Mariage Parfait', style='Lambic - Kriek', abv=8.0, ibu=14, brewery='Brouwerij Boon', rate=3.82, volume='375ml Bottle', price=890.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/46538')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-eylenbosch-oude-gueuze/5502985', name='Oude Gueuze', style='Lambic - Gueuze', abv=5.8, ibu=20, brewery='Brouwerij Eylenbosch', rate=3.75, volume='750ml Bottle', price=2550.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5502985')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-eylenbosch-oude-kriek/4139485', name='Oude Kriek', style='Lambic - Kriek', abv=6.2, ibu=0, brewery='Brouwerij Eylenbosch', rate=3.69, volume='750ml Bottle', price=3150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4139485')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-eylenbosch-schaarbeekse-oude-kriek/4808082', name='Schaarbeekse Oude Kriek', style='Lambic - Kriek', abv=6.2, ibu=0, brewery='Brouwerij Eylenbosch', rate=3.87, volume='750ml Bottle', price=3750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4808082')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-kestemont-blauwe-bes/5327027', name='Blauwe Bes', style='Lambic - Fruit', abv=5.5, ibu=0, brewery='Brouwerij Kestemont', rate=3.72, volume='375ml Bottle', price=2100.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5327027')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-kestemont-blauwe-bes/5327027', name='Blauwe Bes', style='Lambic - Fruit', abv=5.5, ibu=0, brewery='Brouwerij Kestemont', rate=3.72, volume='750ml Bottle', price=3800.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5327027')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-lindemans-apple-pomme/7896', name='Apple / Pomme', style='Lambic - Fruit', abv=3.5, ibu=12, brewery='Brouwerij Lindemans', rate=3.49, volume='250ml Bottle', price=300.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/7896')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-mort-subite-kriek-lambic/27073', name='Kriek Lambic', style='Lambic - Kriek', abv=4.0, ibu=0, brewery='Brouwerij Mort Subite', rate=3.5, volume='250ml Bottle', price=380.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/27073')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-rodenbach-rodenbach-classic/9198', name='Rodenbach Classic', style='Sour - Flanders Red Ale', abv=5.2, ibu=30, brewery='Brouwerij Rodenbach', rate=3.45, volume='330ml Bottle', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/9198')
# BeerPriceSql(url='https://untappd.com/b/casey-brewing-and-blending-funky-blender-preserves-apricot-nectarine/3906020', name='Funky Blender Preserves: Apricot + Nectarine (Perfection/Independence 9/4/19)', style='Farmhouse Ale - Saison', abv=6.0, ibu=0, brewery='Casey Brewing & Blending', rate=4.3, volume='750ml Bottle', price=3500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3906020')
# BeerPriceSql(url='https://untappd.com/b/delirium-huyghe-brewery-delirium-red/33040', name='Delirium Red', style='Fruit Beer', abv=8.0, ibu=10, brewery='Delirium - Huyghe Brewery', rate=3.58, volume='330ml Bottle', price=650.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/33040')
# BeerPriceSql(url='https://untappd.com/b/dok-brewing-company-adc-vieille-brunoise/4676994', name='ADC Vieille Brunoise', style='Sour - Flanders Oud Bruin', abv=7.0, ibu=0, brewery='Dok\u2008Brewing\u2008Company', rate=3.86, volume='750ml Bottle', price=2650.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4676994')
# BeerPriceSql(url='https://untappd.com/b/geuzestekerij-de-cam-oude-geuze-de-cam-2023/5398070', name='Oude Geuze De Cam (2023)', style='Lambic - Gueuze', abv=6.0, ibu=0, brewery='Geuzestekerij De Cam', rate=4.04, volume='750ml Bottle', price=2850.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5398070')
# BeerPriceSql(url='https://untappd.com/b/granizo-betta-cuatro/4402287', name='Betta.Cuatro', style='Sour - Fruited', abv=6.0, ibu=0, brewery='Granizo', rate=4.04, volume='500ml Can', price=2250.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4402287')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-oude-abricot-tilquin-a-l-ancienne-2023-2024/5806050', name="Oude Abricot Tilquin à l'Ancienne (2023-2024)", style='Lambic - Fruit', abv=6.3, ibu=0, brewery='Gueuzerie Tilquin', rate=4.06, volume='375ml Bottle', price=2150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5806050')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-oude-gueuze-tilquin-a-l-ancienne/59861', name="Oude Gueuze Tilquin à l'Ancienne", style='Lambic - Gueuze', abv=7.0, ibu=14, brewery='Gueuzerie Tilquin', rate=4.0, volume='750ml Bottle', price=2150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/59861')
# BeerPriceSql(url='https://untappd.com/b/hanssens-artisanaal-cassis-2024/5816760', name='Cassis (2024)', style='Lambic - Fruit', abv=6.0, ibu=0, brewery='Hanssens Artisanaal', rate=3.6, volume='375ml Bottle', price=1950.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5816760')
# BeerPriceSql(url='https://untappd.com/b/kasteel-brouwerij-vanhonsebrouck-kasteel-rouge/6890', name='Kasteel Rouge', style='Fruit Beer', abv=8.0, ibu=0, brewery='Kasteel Brouwerij Vanhonsebrouck', rate=3.59, volume='330ml Bottle', price=520.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6890')
# BeerPriceSql(url='https://untappd.com/b/lambiek-fabriek-single-and-wild-colon-elle-2024/6036401', name='Single & Wild Colon-Elle (2024)', style='Lambic - Other', abv=8.5, ibu=0, brewery='Lambiek Fabriek', rate=3.92, volume='750ml Bottle', price=3250.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6036401')
# BeerPriceSql(url='https://untappd.com/b/metaphore-vorrei-un-aperitivo/5162667', name='Vorrei Un Aperitivo', style='Wild Ale - Other', abv=4.6, ibu=0, brewery='Métaphore', rate=3.97, volume='750ml Bottle', price=4150.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5162667')
# BeerPriceSql(url='https://untappd.com/b/paradox-alpies-you-sour/5640843', name='Alpies You Sour', style='Sour - Fruited', abv=6.0, ibu=12, brewery='Paradox', rate=3.88, volume='500ml Can', price=440.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5640843')
# BeerPriceSql(url='https://untappd.com/b/paradox-michelada/3864204', name='Michelada', style='Spiced / Herbed Beer', abv=3.0, ibu=10, brewery='Paradox', rate=3.97, volume='330ml Can', price=380.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3864204')
# BeerPriceSql(url='https://untappd.com/b/sabotage-lost-planet-guava-strawberry-and-mint/6178819', name='Lost Planet: Guava, Strawberry & Mint', style='Sour - Berliner Weisse', abv=4.5, ibu=0, brewery='Sabotage', rate=0, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6178819')
# BeerPriceSql(url='https://untappd.com/b/sabotage-lost-planet-raspberry-and-hibiscus/5798978', name='Lost Planet: Raspberry & Hibiscus', style='Sour - Fruited Berliner Weisse', abv=4.5, ibu=0, brewery='Sabotage', rate=4.11, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5798978')
# BeerPriceSql(url='https://untappd.com/b/sako-brewery-adelaar-kriek/5787595', name='Adelaar Kriek', style='Lambic - Kriek', abv=6.5, ibu=0, brewery='Sako Brewery', rate=3.77, volume='375ml Bottle', price=1750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5787595')
# BeerPriceSql(url='https://untappd.com/b/sako-brewery-adelaar-oude-geuze-2024/5815893', name='Adelaar Oude Geuze (2024)', style='Lambic - Gueuze', abv=6.5, ibu=0, brewery='Sako Brewery', rate=3.8, volume='375ml Bottle', price=1750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5815893')
# BeerPriceSql(url='https://untappd.com/b/sako-brewery-geuze-adelaar-elderflower-2022/5675272', name='Geuze Adelaar Elderflower (2022)', style='Lambic - Gueuze', abv=6.5, ibu=0, brewery='Sako Brewery', rate=3.31, volume='750ml Bottle', price=3200.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5675272')
# BeerPriceSql(url='https://untappd.com/b/sako-brewery-geuze-adelaar-spiced-2022/5675271', name='Geuze Adelaar Spiced (2022)', style='Lambic - Gueuze', abv=6.5, ibu=0, brewery='Sako Brewery', rate=3.56, volume='750ml Bottle', price=2450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5675271')
# BeerPriceSql(url='https://untappd.com/b/selfmade-brewery-tomato-method/3703753', name='Tomato Method', style='Sour - Tomato / Vegetable Gose', abv=5.6, ibu=12, brewery='Selfmade Brewery', rate=3.91, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3703753')
# BeerPriceSql(url='https://untappd.com/b/selfmade-brewery-tomato-method-hot-paprika/6109902', name='Tomato Method Hot Paprika', style='Sour - Tomato / Vegetable Gose', abv=5.4, ibu=10, brewery='Selfmade Brewery', rate=4.04, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6109902')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-glowing-up/6181935', name='Glowing Up', style='Sour - Fruited', abv=5.0, ibu=0, brewery='Stamm Brewing', rate=3.77, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6181935')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-nomadland/6007234', name='Nomadland', style='Sour - Fruited', abv=7.0, ibu=0, brewery='Stamm Brewing', rate=3.92, volume='500ml Can', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6007234')
# BeerPriceSql(url='https://untappd.com/b/stamm-brewing-velvet-valley/6151332', name='Velvet Valley', style='Sour - Fruited', abv=7.0, ibu=0, brewery='Stamm Brewing', rate=3.89, volume='500ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6151332')
# BeerPriceSql(url='https://untappd.com/b/stekerij-ambreus-oude-geuze-a-l-ancienne-2023/5870480', name="Oude Geuze à l'Ancienne (2023)", style='Lambic - Gueuze', abv=6.7, ibu=7, brewery='Stekerij Ambreus', rate=3.99, volume='375ml Bottle', price=1550.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5870480')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-groove-in-a-big-city/6157350', name='Groove In A Big City', style='Sour - Fruited', abv=7.0, ibu=0, brewery='Zagovor Brewery', rate=4.03, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6157350')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-jungle-in-a-big-city/3874370', name='Jungle In A Big City', style='Sour - Fruited', abv=6.0, ibu=10, brewery='Zagovor Brewery', rate=4.05, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3874370')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-patch/3128742', name='Patch', style='Sour - Fruited Gose', abv=5.5, ibu=10, brewery='Zagovor Brewery', rate=4.09, volume='500ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3128742')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-stencil/2564940', name='Stencil', style='Sour - Fruited Gose', abv=7.0, ibu=10, brewery='Zagovor Brewery', rate=3.99, volume='450ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2564940')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-techne-in-a-big-city/5608597', name='Techne In A Big City', style='Sour - Fruited', abv=5.0, ibu=0, brewery='Zagovor Brewery', rate=4.11, volume='450ml Can', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5608597')
# BeerPriceSql(url='https://untappd.com/b/privat-brauerei-zotler-hefeweizen-hell/101789', name='Hefeweizen Hell', style='Wheat Beer - Hefeweizen', abv=5.2, ibu=11, brewery='Privat-Brauerei Zötler', rate=3.56, volume='500ml Bottle', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/101789')
# BeerPriceSql(url='https://untappd.com/b/schneider-weisse-g-schneider-and-sohn-aventinus-tap06/16851', name='Aventinus (TAP06)', style='Bock - Weizendoppelbock', abv=8.2, ibu=16, brewery='Schneider Weisse G. Schneider & Sohn', rate=3.81, volume='500ml Bottle', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/16851')
# BeerPriceSql(url='https://untappd.com/b/schneider-weisse-g-schneider-and-sohn-festweisse-tap04/11827', name='Festweisse (TAP04)', style='Wheat Beer - Hefeweizen', abv=6.2, ibu=28, brewery='Schneider Weisse G. Schneider & Sohn', rate=3.65, volume='500ml Bottle', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/11827')
# BeerPriceSql(url='https://untappd.com/b/schneider-weisse-g-schneider-and-sohn-helle-weisse-tap01/40151', name='Helle Weisse (TAP01)', style='Wheat Beer - Hefeweizen', abv=4.9, ibu=14, brewery='Schneider Weisse G. Schneider & Sohn', rate=3.61, volume='500ml Bottle', price=450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/40151')
# BeerPriceSql(url='https://untappd.com/b/schneider-weisse-g-schneider-and-sohn-hopfenweisse-tap05/11027', name='Hopfenweisse (TAP05)', style='Wheat Beer - Hopfenweisse', abv=8.2, ibu=40, brewery='Schneider Weisse G. Schneider & Sohn', rate=3.78, volume='500ml Bottle', price=500.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/11027')
# BeerPriceSql(url='https://untappd.com/b/schneider-weisse-g-schneider-and-sohn-kristall-tap02/11823', name='Kristall (TAP02)', style='Wheat Beer - Kristallweizen', abv=5.3, ibu=16, brewery='Schneider Weisse G. Schneider & Sohn', rate=3.51, volume='500ml Bottle', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/11823')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-feierabend/1116335', name='Feierabend', style='Wheat Beer - Hopfenweisse', abv=5.5, ibu=20, brewery='Zagovor Brewery', rate=3.73, volume='450ml Bottle', price=360.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/1116335')
# BeerPriceSql(url='https://untappd.com/b/4brewers-marionetka/6030175', name='Марионетка', style='Pumpkin / Yam Beer', abv=6.9, ibu=0, brewery='4BREWERS', rate=3.8, volume='500ml Can', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6030175')
# BeerPriceSql(url='https://untappd.com/b/jaws-brewery-lost-pumpkins/2897680', name='Lost Pumpkins', style='Pumpkin / Yam Beer', abv=7.3, ibu=20, brewery='Jaws Brewery', rate=3.73, volume='500ml Bottle', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2897680')
# BeerPriceSql(url='https://untappd.com/b/stadshaven-brouwerij-redhead-ale/5248281', name='Redhead Ale', style='Red Ale - Other', abv=5.8, ibu=25, brewery='Stadshaven Brouwerij', rate=3.26, volume='330ml Bottle', price=480.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5248281')
# BeerPriceSql(url='https://untappd.com/b/zagovor-brewery-farbe-and-rauch/6126218', name='Farbe & Rauch', style='Rauchbier', abv=5.0, ibu=30, brewery='Zagovor Brewery', rate=3.71, volume='500ml Can', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6126218')
# BeerPriceSql(url='https://untappd.com/b/abbaye-notre-dame-de-saint-remy-trappistes-rochefort-8/11473', name='Trappistes Rochefort 8', style='Belgian Strong Dark Ale', abv=9.2, ibu=22, brewery='Abbaye Notre-Dame de Saint-Rémy', rate=3.84, volume='330ml Bottle', price=580.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/11473')
# BeerPriceSql(url='https://untappd.com/b/abbaye-notre-dame-de-saint-remy-trappistes-rochefort-triple-extra/3986134', name='Trappistes Rochefort Triple Extra', style='Belgian Tripel', abv=8.1, ibu=35, brewery='Abbaye Notre-Dame de Saint-Rémy', rate=3.76, volume='330ml Bottle', price=580.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3986134')
# BeerPriceSql(url='https://untappd.com/b/brewery-de-meester-land-van-de-meester/5758296', name='Land Van De Meester', style='Belgian Strong Dark Ale', abv=11.0, ibu=0, brewery='Brewery De Meester', rate=3.79, volume='500ml Bottle', price=1050.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5758296')
# BeerPriceSql(url='https://untappd.com/b/brewery-de-meester-maitre-tripel-red-wine-barrel-aged/3812442', name='Maitre Tripel Red Wine Barrel Aged', style='Belgian Tripel', abv=9.0, ibu=0, brewery='Brewery De Meester', rate=3.59, volume='330ml Bottle', price=890.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/3812442')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-bosteels-tripel-karmeliet/6511', name='Tripel Karmeliet', style='Belgian Tripel', abv=8.4, ibu=16, brewery='Brouwerij Bosteels', rate=3.98, volume='330ml Bottle', price=580.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/6511')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-cornelissen-herkenrode-abbey-vesper/2417789', name='Herkenrode Abbey Vesper', style='Belgian Tripel', abv=9.0, ibu=30, brewery='Brouwerij Cornelissen', rate=3.52, volume='330ml Bottle', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2417789')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-brabandere-kwaremont/26918', name='Kwaremont', style='Belgian Blonde', abv=6.6, ibu=25, brewery='Brouwerij De Brabandere', rate=3.49, volume='330ml Bottle', price=420.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/26918')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-halve-maan-straffe-hendrik-brugs-quadrupel-bier-11-deg/41289', name='Straffe Hendrik Brugs Quadrupel Bier 11°', style='Belgian Quadrupel', abv=11.0, ibu=35, brewery='Brouwerij De Halve Maan', rate=3.89, volume='300ml Bottle', price=680.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/41289')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-halve-maan-straffe-hendrik-brugs-tripel-bier-9-deg/9601', name='Straffe Hendrik Brugs Tripel Bier 9°', style='Belgian Tripel', abv=9.0, ibu=35, brewery='Brouwerij De Halve Maan', rate=3.76, volume='330ml Bottle', price=620.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/9601')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-der-trappisten-van-westmalle-westmalle-trappist-dubbel/4168', name='Westmalle Trappist Dubbel', style='Belgian Dubbel', abv=7.0, ibu=30, brewery='Brouwerij der Trappisten van Westmalle', rate=3.69, volume='330ml Bottle', price=490.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4168')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-der-trappisten-van-westmalle-westmalle-trappist-tripel/487', name='Westmalle Trappist Tripel', style='Belgian Tripel', abv=9.5, ibu=40, brewery='Brouwerij der Trappisten van Westmalle', rate=3.81, volume='330ml Bottle', price=550.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/487')
# BeerPriceSql(url='https://untappd.com/b/de-struise-brouwers-pannepot-vintage-ale/5179823', name='Pannepot Vintage Ale', style='Dark Ale', abv=10.0, ibu=27, brewery='De Struise Brouwers', rate=3.82, volume='330ml Bottle', price=850.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/5179823')
# BeerPriceSql(url='https://untappd.com/b/de-struise-brouwers-sint-amatus-oostvleteren-12/26271', name='Sint Amatus - Oostvleteren 12', style='Belgian Quadrupel', abv=10.5, ibu=23, brewery='De Struise Brouwers', rate=3.87, volume='330ml Bottle', price=950.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/26271')
# BeerPriceSql(url='https://untappd.com/b/de-struise-brouwers-sint-amatus-reserva-oostvleteren-12-2021/4687104', name='Sint Amatus Reserva - Oostvleteren 12 (2021)', style='Belgian Quadrupel', abv=10.5, ibu=0, brewery='De Struise Brouwers', rate=3.87, volume='330ml Bottle', price=950.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/4687104')
# BeerPriceSql(url='https://untappd.com/b/leroy-breweries-poperings-hommelbier/836', name='Poperings Hommelbier', style='Belgian Strong Golden Ale', abv=7.5, ibu=35, brewery='Leroy Breweries', rate=3.45, volume='330ml Bottle', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/836')
# BeerPriceSql(url='https://untappd.com/b/leroy-breweries-poperings-hommelbier-dry-hopping/713509', name='Poperings Hommelbier Dry Hopped', style='IPA - Belgian', abv=7.5, ibu=45, brewery='Leroy Breweries', rate=3.48, volume='330ml Bottle', price=400.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/713509')
# BeerPriceSql(url='https://untappd.com/b/leroy-breweries-watou-s-witbier-biere-blanche-watou/2170676', name="Watou's Witbier / Bière Blanche Watou", style='Wheat Beer - Witbier / Blanche', abv=5.0, ibu=11, brewery='Leroy Breweries', rate=3.18, volume='330ml Bottle', price=380.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/2170676')
# BeerPriceSql(url='https://untappd.com/b/leroy-breweries-yperman/11874', name='Yperman', style='Pale Ale - Belgian', abv=5.5, ibu=23, brewery='Leroy Breweries', rate=3.01, volume='250ml Bottle', price=350.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/11874')
# BeerPriceSql(url='https://untappd.com/b/oud-beersel-bersalis-tripel/20141', name='Bersalis Tripel', style='Belgian Tripel', abv=9.5, ibu=0, brewery='Oud Beersel', rate=3.59, volume='330ml Bottle', price=750.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/20141')
# BeerPriceSql(url='https://untappd.com/b/oud-beersel-bersalis-tripel-oak-aged/975409', name='Bersalis Tripel Oak Aged', style='Sour - Other', abv=10.5, ibu=0, brewery='Oud Beersel', rate=3.68, volume='370mL Bottle', price=1450.0, date_parsed='2025-03-19', venue='RULE taproom', img='https://labels.untappd.com/975409')
# ...
# BeerPriceSql(url='https://untappd.com/b/ashram-cider-sidr-s-klubnikoj/5010343', name='Сидр с Клубникой', style='Cider - Other Fruit', abv=5.5, ibu=0, brewery='Ashram Cider', rate=4.21, volume='750ml Bottle', price=1800.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5010343')
# BeerPriceSql(url='https://untappd.com/b/lya-fuar-de-nizhnij-novgorod-assamblyazh-12/4437985', name='Ассамбляж 12', style='Cider - Dry', abv=5.5, ibu=0, brewery='Ля Фуар Дэ Нижний Новгород', rate=4.02, volume='750ml Bottle', price=850.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4437985')
# BeerPriceSql(url='https://untappd.com/b/lya-fuar-de-nizhnij-novgorod-baron-de-barrik/5752335', name='Барон де Баррик', style='Cider - Dry', abv=5.5, ibu=0, brewery='Ля Фуар Дэ Нижний Новгород', rate=4.0, volume='750ml Bottle', price=850.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5752335')
# BeerPriceSql(url='https://untappd.com/b/breezinghead-dikij-sad-2023/5848174', name='Дикий Сад 2023', style='Cider - Dry', abv=6.0, ibu=0, brewery='Breezinghead', rate=3.89, volume='450ml Bottle', price=590.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5848174')
# BeerPriceSql(url='https://untappd.com/b/breezinghead-zapretnyj-plod-2023/5848177', name='Запретный Плод 2023', style='Cider - Traditional / Apfelwein', abv=5.3, ibu=0, brewery='Breezinghead', rate=3.82, volume='450ml Bottle', price=590.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5848177')
# BeerPriceSql(url='https://untappd.com/b/yasnaya-polyana-sidr-suhoj-24/6091362', name="Сидр Сухой '24", style='Cider - Dry', abv=4.8, ibu=0, brewery='Ясная Поляна', rate=3.97, volume='330ml Bottle', price=390.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/6091362')
# Parsed 103
# Parsing Братья Крафт
# BeerPriceSql(url='https://untappd.com/b/de-struise-brouwers-black-damnation-xvi-ivan-the-terrible/498762', name='Black Damnation XVI - Ivan The Terrible', style='Stout - Russian Imperial', abv=15.0, ibu=140, brewery='De Struise Brouwers', rate=4.21, volume='330ml Bottle', price=1300.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/498762')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-kees-barrel-project-2024-midnight-black/5884098', name='Barrel Project 2024 Midnight Black', style='Stout - Russian Imperial', abv=14.9, ibu=65, brewery='Brouwerij Kees', rate=4.0, volume='330ml Can', price=1030.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5884098')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-kees-it-s-a-sin/5738126', name='It’s A Sin', style='Stout - Imperial / Double', abv=13.8, ibu=56, brewery='Brouwerij Kees', rate=3.96, volume='330ml Can', price=900.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5738126')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-kees-export-porter-1750/1072271', name='Export Porter 1750', style='Porter - Imperial / Double', abv=10.5, ibu=108, brewery='Brouwerij Kees', rate=3.85, volume='330ml Can', price=820.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/1072271')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-dochter-van-de-korenaar-sans-pardon/990955', name='Sans Pardon', style='Stout - Russian Imperial', abv=11.0, ibu=50, brewery='Brouwerij De Dochter van de Korenaar', rate=3.83, volume='330ml Bottle', price=750.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/990955')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-kees-fate-loves-the-fearless/5882692', name='Fate Loves the Fearless', style='Barleywine - American', abv=14.8, ibu=0, brewery='Brouwerij Kees', rate=3.91, volume='330ml Can', price=930.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5882692')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-sint-sixtusabdij-van-westvleteren-trappist-westvleteren-12/4680', name='Trappist Westvleteren 12', style='Belgian Quadrupel', abv=10.2, ibu=38, brewery='Brouwerij De Sint-Sixtusabdij van Westvleteren', rate=4.47, volume='330ml Bottle', price=2750.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4680')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-alvinne-cuvee-botte-di-barolo/4776814', name='Cuvée Botte di Barolo', style='Belgian Quadrupel', abv=12.0, ibu=0, brewery='Brouwerij Alvinne', rate=3.88, volume='750ml Bottle', price=2850.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4776814')
# BeerPriceSql(url='https://untappd.com/b/trappistenbrouwerij-de-kievit-b-v-zundert-10-2023/5267961', name='Zundert 10 (2023)', style='Belgian Quadrupel', abv=10.0, ibu=53, brewery='Trappistenbrouwerij de Kievit B.V.', rate=3.96, volume='330ml Bottle', price=650.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5267961')
# BeerPriceSql(url='https://untappd.com/b/brewery-de-meester-maitre-quad/1280408', name='Maître Quad', style='Belgian Quadrupel', abv=9.5, ibu=43, brewery='Brewery De Meester', rate=3.65, volume='330ml Bottle', price=850.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/1280408')
# BeerPriceSql(url='https://untappd.com/b/bieres-de-chimay-chimay-grande-reserve-blue-2024/5723403', name='Chimay Grande Réserve (Blue) (2024)', style='Belgian Strong Dark Ale', abv=9.0, ibu=35, brewery='Bières de Chimay', rate=3.81, volume='330ml Bottle', price=550.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5723403')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-ranke-noir-de-dottignies/12325', name='Noir de Dottignies', style='Belgian Strong Dark Ale', abv=8.5, ibu=46, brewery='Brouwerij De Ranke', rate=3.71, volume='330ml Bottle', price=790.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/12325')
# BeerPriceSql(url='https://untappd.com/b/stadsbrouwerij-artevelde-artevelde-grand-cru/5171696', name='Artevelde Grand Cru', style='Belgian Dubbel', abv=7.3, ibu=0, brewery='Stadsbrouwerij Artevelde', rate=3.54, volume='330ml Bottle', price=640.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5171696')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-der-trappisten-van-westmalle-westmalle-trappist-dubbel/4168', name='Westmalle Trappist Dubbel', style='Belgian Dubbel', abv=7.0, ibu=30, brewery='Brouwerij der Trappisten van Westmalle', rate=3.69, volume='330ml Bottle', price=620.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4168')
# BeerPriceSql(url='https://untappd.com/b/brewery-john-martin-brewery-timmermans-blanche-de-brabant/81078', name='Blanche de Brabant', style='Wheat Beer - Witbier / Blanche', abv=5.0, ibu=0, brewery='Brewery John Martin & Brewery Timmermans', rate=3.51, volume='500ml Can', price=380.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/81078')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-oude-pinot-gris-tilquin-a-l-ancienne-2021-2022/5076675', name="Oude Pinot Gris Tilquin à l'Ancienne (2021-2022)", style='Lambic - Fruit', abv=8.0, ibu=0, brewery='Gueuzerie Tilquin', rate=4.27, volume='750ml Bottle', price=4200.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5076675')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-oude-pinot-noir-tilquin-a-l-ancienne-2021-2022/5076674', name="Oude Pinot Noir Tilquin à l'Ancienne (2021-2022)", style='Lambic - Fruit', abv=8.0, ibu=0, brewery='Gueuzerie Tilquin', rate=4.24, volume='750ml Bottle', price=4100.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5076674')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-oude-roussanne-tilquin-a-l-ancienne-2021-2022/4962452', name="Oude Roussanne Tilquin à l'Ancienne (2021-2022)", style='Lambic - Fruit', abv=8.0, ibu=0, brewery='Gueuzerie Tilquin', rate=4.2, volume='750ml Bottle', price=4200.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4962452')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-oude-riesling-tilquin-a-l-ancienne-2021-2022/5076676', name="Oude Riesling Tilquin à l'Ancienne (2021-2022)", style='Lambic - Fruit', abv=7.7, ibu=0, brewery='Gueuzerie Tilquin', rate=4.27, volume='750ml Bottle', price=4250.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5076676')
# BeerPriceSql(url='https://untappd.com/b/gueuzerie-tilquin-oude-gueuze-tilquin-a-l-ancienne-lambics-vieillis-en-futs-de-cognac/5307883', name="Oude Gueuze Tilquin à l'Ancienne - Lambics Vieillis en Fûts de Cognac", style='Lambic - Gueuze', abv=7.6, ibu=0, brewery='Gueuzerie Tilquin', rate=4.34, volume='750ml Bottle', price=4800.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5307883')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-nocturne-season-21-22-blend-no-47/4969950', name='3 Fonteinen Nocturne (season 21|22) Blend No. 47', style='Sour - Flanders Oud Bruin', abv=8.0, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.16, volume='750ml Bottle', price=3500.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4969950')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-vintage-2019/5019748', name='3 Fonteinen Oude Geuze Vintage 2019', style='Lambic - Gueuze', abv=6.8, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.43, volume='375ml Bottle', price=2400.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5019748')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-doesjel-season-19-20-blend-no-85/4667212', name='3 Fonteinen Doesjel (season 19|20) Blend No. 85', style='Lambic - Gueuze', abv=6.5, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.16, volume='750ml Bottle', price=2100.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4667212')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-cuvee-armand-and-gaston-season-19-20-blend-no-7/4675431', name='3 Fonteinen Oude Geuze Cuvée Armand & Gaston (season 19|20) Blend No. 7', style='Lambic - Gueuze', abv=6.9, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.28, volume='375ml Bottle', price=1430.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4675431')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-season-21-22-blend-no-64/5221651', name='3 Fonteinen Oude Geuze (season 21|22) Blend No. 64', style='Lambic - Gueuze', abv=7.1, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.27, volume='750ml Bottle', price=2550.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5221651')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-season-21-22-blend-no-66/5039228', name='3 Fonteinen Oude Geuze (season 21|22) Blend No. 66', style='Lambic - Gueuze', abv=7.1, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.21, volume='375ml Bottle', price=1350.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5039228')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-season-21-22-blend-no-125/5317500', name='3 Fonteinen Oude Geuze (season 21|22) Blend No. 125', style='Lambic - Gueuze', abv=6.7, ibu=0, brewery='Brouwerij 3 Fonteinen', rate=4.17, volume='750ml Bottle', price=2550.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5317500')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-boon-horal-s-oude-geuze-mega-blend-2021/4290063', name="HORAL's Oude Geuze Mega Blend (2021)", style='Lambic - Gueuze', abv=7.0, ibu=0, brewery='Brouwerij Boon', rate=4.03, volume='750ml Bottle', price=3000.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4290063')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-boon-horal-s-oude-geuze-megablend-2024/5801708', name="HORAL's Oude Geuze Mega Blend (2024)", style='Lambic - Gueuze', abv=7.0, ibu=18, brewery='Brouwerij Boon', rate=3.93, volume='750ml Bottle', price=3400.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5801708')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-boon-oude-geuze-dekoninck-2020/4451889', name='Oude Geuze Dekoninck (2020)', style='Lambic - Gueuze', abv=7.0, ibu=0, brewery='Brouwerij Boon', rate=4.11, volume='375ml Bottle', price=1170.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4451889')
# BeerPriceSql(url='https://untappd.com/b/oud-beersel-oude-geuze-vieille/15215', name='Oude Geuze (Vieille)', style='Lambic - Gueuze', abv=6.5, ibu=18, brewery='Oud Beersel', rate=3.77, volume='375ml Bottle', price=1250.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/15215')
# BeerPriceSql(url='https://untappd.com/b/oud-beersel-oude-kriek-vieille-2021/4903878', name='Oude Kriek (Vieille) (2021)', style='Lambic - Kriek', abv=6.0, ibu=0, brewery='Oud Beersel', rate=4.16, volume='375ml Bottle', price=1480.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/4903878')
# BeerPriceSql(url='https://untappd.com/b/boerenerf-muscabella-2023/5784178', name='Muscabella (2023)', style='Lambic - Other', abv=6.8, ibu=0, brewery='Boerenerf', rate=4.19, volume='375ml Bottle', price=1900.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5784178')
# BeerPriceSql(url='https://untappd.com/b/brouwerij-de-dochter-van-de-korenaar-la-renaissance-grand-cru-no-iii/5179601', name='La Renaissance Grand Cru No. III', style='IPA - English', abv=7.0, ibu=0, brewery='Brouwerij De Dochter van de Korenaar', rate=3.74, volume='750ml Bottle', price=3600.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5179601')
# BeerPriceSql(url='https://untappd.com/b/brewdog-punk-ipa/5702', name='Punk IPA', style='IPA - American', abv=5.2, ibu=35, brewery='BrewDog', rate=3.71, volume='500ml Can', price=440.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5702')
# BeerPriceSql(url='https://untappd.com/b/schneider-weisse-g-schneider-and-sohn-aventinus-eisbock-tap09-2023/5693783', name='Aventinus Eisbock (TAP09) (2023)', style='Bock - Eisbock', abv=12.0, ibu=15, brewery='Schneider Weisse G. Schneider & Sohn', rate=3.99, volume='330ml Bottle', price=580.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5693783')
# BeerPriceSql(url='https://untappd.com/b/schlenkerla-heller-brau-trum-aecht-schlenkerla-erle-schwarzbier/5456891', name='Aecht Schlenkerla Erle – Schwarzbier', style='Rauchbier', abv=4.3, ibu=0, brewery='Schlenkerla ("Heller-Bräu" Trum)', rate=3.83, volume='500ml Bottle', price=300.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/5456891')
# BeerPriceSql(url='https://untappd.com/b/de-struise-brouwers-xxx-rye-triple-reserva-bourbon-barrel-aged/268216', name='XXX Rye Triple Reserva Bourbon Barrel Aged', style='Rye Wine', abv=10.0, ibu=0, brewery='De Struise Brouwers', rate=3.97, volume='330ml Bottle', price=1150.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/268216')
# BeerPriceSql(url='https://untappd.com/b/fournier-freres-producteurs-eleveurs-cidre-artisanal-brut/975396', name='Cidre Artisanal Brut', style='Cider - Traditional / Apfelwein', abv=4.5, ibu=0, brewery='Fournier-Frères Producteurs-Eleveurs', rate=3.84, volume='750ml Bottle', price=1200.0, date_parsed='2025-03-19', venue='Братья Крафт', img='https://labels.untappd.com/975396')
# Parsed 39
